# %%
from wrapper  import Kanbanize
empresa = "easyon"
apikey = ""
k = Kanbanize(empresa, apikey)
k.get_all_tasks(37,format='dict')

r2 = k.get_task_details(37,968)
r1 = k.get_all_tasks(37,format='json')


print(r2)
print(r1)
# Out:
# {'taskid': '968', 'boardid': '37', 'title': 'Flujo Tareas', 'description': 'Received as e-mail on 2019-04-29 22:42:08 :\nFrom: claudio.carcamo.s@gmail.com\nTo: flow_easyon@kanbanize.com\nCc:\n\n\n\n\n\n\n\n\n\n\nSaludos Cordiales, atte\nClaudio Cárcamo Santibáñez\n[claudio.carcamo.s@gmail.com](mailto:claudio.carcamo.s@gmail.com)\ncelular +56 9 8922 6152', 'type': 'None', 'assignee': 'None', 'subtasks': '0', 'subtaskscomplete': '0', 'color': '#34a97b', 'priority': 'Average', 'size': None, 'deadline': None, 'deadlineoriginalformat': None, 'extlink': None, 'tags': None, 'leadtime': 0, 'blocked': '0', 'blockedreason': None, 'columnname': 'INICIO', 'lanename': 'Default Swimlane', 'subtaskdetails': [], 'columnid': 'backlog_548', 'laneid': '98', 'position': '0', 'workflow': 0, 'workflow_id': 127, 'attachments': {}, 'columnpath': 'INICIO', 'loggedtime': 0, 'reporter': 'Claudio', 'customfields': [], 'updatedat': '2019-04-29 22:42:09'}
# ...
