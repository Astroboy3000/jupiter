# %%
from wrapper  import Kanbanize
import xml.etree.ElementTree as ET
import pandas as pd

import numpy as np

empresa = ""
apikey = ""

k = Kanbanize(empresa, apikey)

r1 = k.get_all_tasks(37,format='dict')
df = pd.DataFrame(r1)

#Ordenar Columnas 
respuesta = df.reindex(['taskid','position','type','assignee','title','description','subtasks','subtaskscomplete','color','priority','size','deadline','deadlineoriginalformat','extlink','tags','columnid','laneid','leadtime','blocked','blockedreason','columnname','lanename','logedtime','boardparent','archivedat','reporter','createdat','workflow_name','workflow,workflow_id','columnpath','linkschild','linksparent','linksrelated','linkspredecessor','linkssuccessor','updatedat'], axis=1)

r1 = respuesta.groupby('columnname')['taskid'].agg(['count'])
r3 = respuesta.groupby('assignee')['columnname'].agg(['count'])

r4 = respuesta.groupby('deadlineoriginalformat')['taskid'].agg(['count'])
r5 = respuesta.groupby('deadline')['leadtime'].agg(['mean'])

#Agrupacion por Asignado y Columna
grp = respuesta.groupby(['assignee',  'columnpath', 'columnname'])['leadtime'].count()

#Genera archivo csv
respuesta.to_csv (r'./export_dataframe.csv', index = None, header=True) 
grp.to_csv (r'./group_dataframe.csv', index = True, header=True)

print(r1)
print(r3)
print(r4)
print(r5)

print(grp)
# Out:
#                              count
# columnname
# APROBADA                         3
# ASIGNADO                         1
# EMITIR POLIZA                    2
# ENVIAR COMPARATIVO               2
# EVALUAR                          1
# INICIO                           1
# NUEVOS ANTECEDENTES              1
# PREPARAR CUADRO COMPARATIVO      5
# RECHAZADA                        1
#           count
# assignee
# Claudio       8
# None          3
# amiquelc      6
#                         count
# deadlineoriginalformat
# 2019-05-01                  1
# 2019-05-02                  1
# 2019-05-03                  2
# 2019-05-04                  3
# 2019-05-06                  2
# 2019-05-07                  2
# 2019-05-08                  2
# 2019-05-09                  1
# 2019-05-10                  2
#           mean
# deadline
# 01 May      25
# 02 May      25
# 03 May      25
# 04 May      25
# 06 May      25
# 07 May      25
# 08 May      14
# 09 May      25
# 10 May      25
# assignee  columnpath                        columnname
# Claudio   ANTECEDENTES.EVALUAR              EVALUAR                        1
#           PREPARAR CUADRO COMPARATIVO       PREPARAR CUADRO COMPARATIVO    3
#           RECIBIR PROPUESTA.APROBADA        APROBADA                       2
#           RECIBIR PROPUESTA.EMITIR POLIZA   EMITIR POLIZA                  2
# None      ASIGNADO                          ASIGNADO                       1
#           INICIO                            INICIO                         1
#           PREPARAR CUADRO COMPARATIVO       PREPARAR CUADRO COMPARATIVO    1
# amiquelc  ANTECEDENTES.NUEVOS ANTECEDENTES  NUEVOS ANTECEDENTES            1
#           ENVIAR COMPARATIVO                ENVIAR COMPARATIVO             2
#           PREPARAR CUADRO COMPARATIVO       PREPARAR CUADRO COMPARATIVO    1
#           RECIBIR PROPUESTA.APROBADA        APROBADA                       1
#           RECIBIR PROPUESTA.RECHAZADA       RECHAZADA                      1
# Name: leadtime, dtype: int64
